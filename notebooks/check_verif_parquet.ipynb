# %%
import pandas as pd

# %%
verif_loc = "/glade/derecho/scratch/dkimpara/goes_10km_train/mpas/mpas_fixed/verif.parquet"

df = pd.read_parquet(verif_loc)

print([c for c in df.columns if "MAESS" in c])
# Out:
# ['MAESS_C07', 'MAESS_C08', 'MAESS_C09', 'MAESS_C10', 'MAESS_C13', 'MAESS_region_right_C07', 'MAESS_region_right_C08', 'MAESS_region_right_C09', 'MAESS_region_right_C10', 'MAESS_region_right_C13', 'MAESS_n_hem_C07', 'MAESS_n_hem_C08', 'MAESS_n_hem_C09', 'MAESS_n_hem_C10', 'MAESS_n_hem_C13', 'MAESS_s_hem_C07', 'MAESS_s_hem_C08', 'MAESS_s_hem_C09', 'MAESS_s_hem_C10', 'MAESS_s_hem_C13']

# %%
print([c for c in df.columns if "PCT" in c and "WS1_" in c])
# Out:
# ['FSS_WS1_C13_PCT255', 'FSS_WS1_C13_PCT235', 'FSS_WS1_C13_PCT_high', 'FSS_WS1_C13_PCT_medium_high', 'FSS_WS1_C13_PCT_medium', 'FSS_WS1_C13_PCT_low', 'FSS_WS1_C13_PCT_none', 'FSS_WS1_C13_PCT255_tropics', 'FSS_WS1_C13_PCT235_tropics', 'FSS_WS1_C13_PCT_high_tropics', 'FSS_WS1_C13_PCT_medium_high_tropics', 'FSS_WS1_C13_PCT_medium_tropics', 'FSS_WS1_C13_PCT_low_tropics', 'FSS_WS1_C13_PCT_none_tropics', 'FSS_WS1_C13_PCT255_region_right', 'FSS_WS1_C13_PCT235_region_right', 'FSS_WS1_C13_PCT_high_region_right', 'FSS_WS1_C13_PCT_medium_high_region_right', 'FSS_WS1_C13_PCT_medium_region_right', 'FSS_WS1_C13_PCT_low_region_right', 'FSS_WS1_C13_PCT_none_region_right', 'FSS_WS1_C09_PCT_clouds_3', 'FSS_WS1_C09_PCT_clouds_2', 'FSS_WS1_C09_PCT_clouds_1', 'FSS_WS1_C09_PCT_moist', 'FSS_WS1_C09_PCT_dry', 'FSS_WS1_C09_PCT_clouds_3_tropics', 'FSS_WS1_C09_PCT_clouds_2_tropics', 'FSS_WS1_C09_PCT_clouds_1_tropics', 'FSS_WS1_C09_PCT_moist_tropics', 'FSS_WS1_C09_PCT_dry_tropics', 'FSS_WS1_C09_PCT_clouds_3_regi
# ...

# %%
print([c for c in df.columns if "confusion" in c and "C13" in c])
# Out:
# ['confusion_C13_obs_high', 'confusion_C13_obs_medium_high', 'confusion_C13_obs_medium', 'confusion_C13_obs_low', 'confusion_C13_obs_none', 'confusion_C13_obs_high_tropics', 'confusion_C13_obs_medium_high_tropics', 'confusion_C13_obs_medium_tropics', 'confusion_C13_obs_low_tropics', 'confusion_C13_obs_none_tropics', 'confusion_C13_obs_high_region_right', 'confusion_C13_obs_medium_high_region_right', 'confusion_C13_obs_medium_region_right', 'confusion_C13_obs_low_region_right', 'confusion_C13_obs_none_region_right']
