# %%
from credit.data import get_forward_data
from glob import glob
import os
import xarray as xr

# %%
all_files = sorted(glob('/glade/campaign/cisl/aiml/wchapman/MLWPS/STAGING/f.e21.CREDIT_climate_[0-9][0-9][0-9][0-9].zarr'))
# all_ERA_files = sorted(glob("/glade/derecho/scratch/ksha/CREDIT_data/ERA5_mlevel_arXiv/SixHourly_y_TOTAL_*.zarr"))

# %%
all_files = sorted(glob('/glade/campaign/cisl/aiml/wchapman/MLWPS/STAGING/coarse_climate/f.e21.CREDIT_climate_*_coarse.zarr'))
# all_ERA_files = sorted(glob("/glade/derecho/scratch/ksha/CREDIT_data/ERA5_mlevel_arXiv/SixHourly_y_TOTAL_*.zarr"))

# %%
all_files
# Out:
# ['/glade/campaign/cisl/aiml/wchapman/MLWPS/STAGING/coarse_climate/f.e21.CREDIT_climate_1979_coarse.zarr',
#  '/glade/campaign/cisl/aiml/wchapman/MLWPS/STAGING/coarse_climate/f.e21.CREDIT_climate_1980_coarse.zarr',
#  '/glade/campaign/cisl/aiml/wchapman/MLWPS/STAGING/coarse_climate/f.e21.CREDIT_climate_1981_coarse.zarr',
#  '/glade/campaign/cisl/aiml/wchapman/MLWPS/STAGING/coarse_climate/f.e21.CREDIT_climate_1982_coarse.zarr',
#  '/glade/campaign/cisl/aiml/wchapman/MLWPS/STAGING/coarse_climate/f.e21.CREDIT_climate_1983_coarse.zarr',
#  '/glade/campaign/cisl/aiml/wchapman/MLWPS/STAGING/coarse_climate/f.e21.CREDIT_climate_1984_coarse.zarr',
#  '/glade/campaign/cisl/aiml/wchapman/MLWPS/STAGING/coarse_climate/f.e21.CREDIT_climate_1985_coarse.zarr',
#  '/glade/campaign/cisl/aiml/wchapman/MLWPS/STAGING/coarse_climate/f.e21.CREDIT_climate_1986_coarse.zarr',
#  '/glade/campaign/cisl/aiml/wchapman/MLWPS/STAGING/coarse_climate/f.e21.CREDIT_climate_1987_coarse.zarr',
# ...

# %%
file = all_files[0]
dataset = get_forward_data(file)
# dataset.to_zarr(os.path.join("/glade/derecho/scratch/dkimpara/test_rechunk", filename))

# %%
dataset
# Out:
# <xarray.Dataset> Size: 64GB
# Dimensions:    (time: 1460, latitude: 192, longitude: 288, level: 10)
# Coordinates:
#   * latitude   (latitude) float64 2kB -90.0 -89.06 -88.12 ... 88.12 89.06 90.0
#   * level      (level) float64 80B 31.23 90.18 156.6 239.0 ... 730.0 873.5 955.9
#   * longitude  (longitude) float64 2kB 0.0 1.25 2.5 3.75 ... 356.2 357.5 358.8
#   * time       (time) object 12kB 1979-01-01 00:00:00 ... 1979-12-31 18:00:00
# Data variables: (12/37)
#     CLDHGH     (time, latitude, longitude) float64 646MB dask.array<chunksize=(4, 192, 288), meta=np.ndarray>
#     CLDLOW     (time, latitude, longitude) float64 646MB dask.array<chunksize=(4, 192, 288), meta=np.ndarray>
#     CLDMED     (time, latitude, longitude) float64 646MB dask.array<chunksize=(4, 192, 288), meta=np.ndarray>
#     CLDTOT     (time, latitude, longitude) float64 646MB dask.array<chunksize=(4, 192, 288), meta=np.ndarray>
# ...

# %%
zscore = get_forward_data('/glade/campaign/cisl/aiml/wchapman/MLWPS/STAGING/std_6h_1979_2010_10lev_1.0deg.nc')

# %%
zscore
# Out:
# <xarray.Dataset> Size: 1kB
# Dimensions:   (level: 10, ilev: 33, lev: 32)
# Coordinates:
#   * level     (level) float64 80B 31.23 90.18 156.6 239.0 ... 730.0 873.5 955.9
#   * ilev      (ilev) float64 264B 2.255 5.032 10.16 18.56 ... 967.5 985.1 1e+03
#   * lev       (lev) float64 256B 3.643 7.595 14.36 24.61 ... 957.5 976.3 992.6
# Data variables: (12/37)
#     CLDHGH    float64 8B ...
#     CLDLOW    float64 8B ...
#     CLDMED    float64 8B ...
#     CLDTOT    float64 8B ...
#     FLDS      float64 8B ...
#     FLNS      float64 8B ...
#     ...        ...
#     TAUY      float64 8B ...
#     TREFHT    float64 8B ...
#     U         (level) float64 80B ...
#     U10       float64 8B ...
#     V         (level) float64 80B ...
#     ZMMU      (level) float64 80B ...

# %%
levels = len(dataset.level)
lat = len(dataset.latitude)
lon = len(dataset.longitude)

# %%
dataset = dataset.chunk({"time": 2,
                         "level": levels,
                         "latitude": lat,
                         "longitude": lon,})

# %%
dataset
# Out:
# <xarray.Dataset> Size: 138GB
# Dimensions:     (time: 8760, level: 16, latitude: 192, longitude: 288,
#                  half_level: 138)
# Coordinates:
#   * half_level  (half_level) int32 552B 1 2 3 4 5 6 ... 133 134 135 136 137 138
#   * latitude    (latitude) float64 2kB -90.0 -89.06 -88.12 ... 88.12 89.06 90.0
#   * level       (level) int64 128B 10 30 40 50 60 70 ... 105 110 120 130 136 137
#   * longitude   (longitude) float64 2kB 0.0 1.25 2.5 3.75 ... 356.2 357.5 358.8
#   * time        (time) datetime64[ns] 70kB 1979-01-01 ... 1979-12-31T23:00:00
# Data variables:
#     Q           (time, level, latitude, longitude) float32 31GB dask.array<chunksize=(2, 16, 192, 288), meta=np.ndarray>
#     Q500        (time, latitude, longitude) float32 2GB dask.array<chunksize=(2, 192, 288), meta=np.ndarray>
#     SP          (time, latitude, longitude) float32 2GB dask.array<chunksize=(2, 192, 288), meta=np.ndarray>
# ...

# %%
dataset.U500
# Out:
# <xarray.DataArray 'U500' (time: 8760, latitude: 192, longitude: 288)> Size: 2GB
# dask.array<rechunk-merge, shape=(8760, 192, 288), dtype=float32, chunksize=(2, 192, 288), chunktype=numpy.ndarray>
# Coordinates:
#   * latitude   (latitude) float64 2kB -90.0 -89.06 -88.12 ... 88.12 89.06 90.0
#   * longitude  (longitude) float64 2kB 0.0 1.25 2.5 3.75 ... 356.2 357.5 358.8
#   * time       (time) datetime64[ns] 70kB 1979-01-01 ... 1979-12-31T23:00:00

# %%
ds = xr.unify_chunks(dataset)[0]
# Out:
# <bound method Dataset.chunk of <xarray.Dataset> Size: 138GB
# Dimensions:     (time: 8760, level: 16, latitude: 192, longitude: 288,
#                  half_level: 138)
# Coordinates:
#   * half_level  (half_level) int32 552B 1 2 3 4 5 6 ... 133 134 135 136 137 138
#   * latitude    (latitude) float64 2kB -90.0 -89.06 -88.12 ... 88.12 89.06 90.0
#   * level       (level) int64 128B 10 30 40 50 60 70 ... 105 110 120 130 136 137
#   * longitude   (longitude) float64 2kB 0.0 1.25 2.5 3.75 ... 356.2 357.5 358.8
#   * time        (time) datetime64[ns] 70kB 1979-01-01 ... 1979-12-31T23:00:00
# Data variables:
#     Q           (time, level, latitude, longitude) float32 31GB dask.array<chunksize=(2, 16, 192, 288), meta=np.ndarray>
#     Q500        (time, latitude, longitude) float32 2GB dask.array<chunksize=(2, 192, 288), meta=np.ndarray>
#     SP          (time, latitude, longitude) float32 2GB dask.array<chunksize=(2, 192, 288), meta=np.ndarray>
# ...

# %%
ds.chunks
# Out:
# Frozen({'time': (2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 
# ...

# %%
ds.drop_encoding()

# %%
ds.to_zarr(os.path.join("/glade/derecho/scratch/dkimpara/test_rechunk", "test2.zarr"))
