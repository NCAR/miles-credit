# %%
from credit.data import get_forward_data
from glob import glob
import os
import xarray as xr
import numpy as np
import pandas as pd

# %%
ds = xr.open_dataset('/glade/campaign/cisl/aiml/wchapman/MLWPS/STAGING/f.e21.CREDIT_climate_1980_ERA5scaled_F32_Qtot.zarr')
# Out:
# /glade/u/home/dkimpara/credit/lib/python3.11/site-packages/xarray/backends/plugins.py:159: RuntimeWarning: 'netcdf4' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# /glade/u/home/dkimpara/credit/lib/python3.11/site-packages/xarray/backends/plugins.py:159: RuntimeWarning: 'scipy' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)

# %%
type(ds['time'].values)
# Out:
# numpy.ndarray

# %%
time_index = xr.CFTimeIndex(ds['time'].values)

# %%
time_index
# Out:
# CFTimeIndex([1980-01-01 00:00:00, 1980-01-01 06:00:00, 1980-01-01 12:00:00,
#              1980-01-01 18:00:00, 1980-01-02 00:00:00, 1980-01-02 06:00:00,
#              1980-01-02 12:00:00, 1980-01-02 18:00:00, 1980-01-03 00:00:00,
#              1980-01-03 06:00:00,
#              ...
#              1980-12-29 12:00:00, 1980-12-29 18:00:00, 1980-12-30 00:00:00,
#              1980-12-30 06:00:00, 1980-12-30 12:00:00, 1980-12-30 18:00:00,
#              1980-12-31 00:00:00, 1980-12-31 06:00:00, 1980-12-31 12:00:00,
#              1980-12-31 18:00:00],
#             dtype='object', length=1460, calendar='noleap', freq='6h')

# %%
ds['time'] = time_index
ds
# Out:
# <xarray.Dataset> Size: 92GB
# Dimensions:    (time: 1460, latitude: 192, longitude: 288, level: 32, ilev: 33)
# Coordinates:
#   * ilev       (ilev) float32 132B 2.255 5.032 10.16 18.56 ... 967.5 985.1 1e+03
#   * latitude   (latitude) float32 768B -90.0 -89.06 -88.12 ... 88.12 89.06 90.0
#   * level      (level) float32 128B 3.643 7.595 14.36 ... 957.5 976.3 992.6
#   * longitude  (longitude) float32 1kB 0.0 1.25 2.5 3.75 ... 356.2 357.5 358.8
#   * time       (time) object 12kB 1980-01-01 00:00:00 ... 1980-12-31 18:00:00
# Data variables: (12/43)
#     CLDHGH     (time, latitude, longitude) float32 323MB ...
#     CLDLOW     (time, latitude, longitude) float32 323MB ...
#     CLDMED     (time, latitude, longitude) float32 323MB ...
#     CLDTOT     (time, latitude, longitude) float32 323MB ...
#     FLDS       (time, latitude, longitude) float32 323MB ...
#     FLNS       (time, latitude, longitude) float32 323MB ...
#     ...         ...
# ...

# %%
ds.time.values.argmax()
# Out:
# 1459

# %%
ds.loc[{'time': ds.time.values[1]}]
# Out:
# <xarray.Dataset> Size: 63MB
# Dimensions:    (latitude: 192, longitude: 288, level: 32, ilev: 33)
# Coordinates:
#   * ilev       (ilev) float32 132B 2.255 5.032 10.16 18.56 ... 967.5 985.1 1e+03
#   * latitude   (latitude) float32 768B -90.0 -89.06 -88.12 ... 88.12 89.06 90.0
#   * level      (level) float32 128B 3.643 7.595 14.36 ... 957.5 976.3 992.6
#   * longitude  (longitude) float32 1kB 0.0 1.25 2.5 3.75 ... 356.2 357.5 358.8
#     time       object 8B 1980-01-01 06:00:00
# Data variables: (12/43)
#     CLDHGH     (latitude, longitude) float32 221kB ...
#     CLDLOW     (latitude, longitude) float32 221kB ...
#     CLDMED     (latitude, longitude) float32 221kB ...
#     CLDTOT     (latitude, longitude) float32 221kB ...
#     FLDS       (latitude, longitude) float32 221kB ...
#     FLNS       (latitude, longitude) float32 221kB ...
#     ...         ...
#     V          (level, latitude, longitude) float32 7MB ...
#     ZMMU       (level, latitude, longitude) float32 7MB ...
# ...

# %%
time_dx.loc[{'time': pd.Timestamp("1980-01-01 00:00:00")}]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/credit/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: Timestamp('1980-01-01 00:00:00')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
ds.sel({'time': pd.Timestamp("1980-05-01 00:00:00")})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/credit/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: Timestamp('1980-05-01 00:00:00')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
dsnp = xr.open_dataset("/glade/work/dkimpara/CREDIT_runs/prescribed_skebs_rollout/1979-01-01T00Z/pred_1979-01-01T00Z_006.nc")

# %%
dsnp.time
# Out:
# <xarray.DataArray 'time' (time: 1)> Size: 8B
# array(['1979-01-01T06:00:00.000000000'], dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 8B 1979-01-01T06:00:00

# %%
dsnp.loc[{'time': [pd.Timestamp("1979-01-01 06:00:00")]}]
# Out:
# <xarray.Dataset> Size: 2GB
# Dimensions:                (ensemble_member_label: 50, time: 1, level: 32,
#                             latitude: 192, longitude: 288)
# Coordinates:
#   * time                   (time) datetime64[ns] 8B 1979-01-01T06:00:00
#   * level                  (level) int64 256B 0 1 2 3 4 5 ... 26 27 28 29 30 31
#   * latitude               (latitude) float32 768B -90.0 -89.06 ... 89.06 90.0
#   * longitude              (longitude) float32 1kB 0.0 1.25 2.5 ... 357.5 358.8
#   * ensemble_member_label  (ensemble_member_label) int64 400B 0 1 2 ... 47 48 49
# Data variables: (12/21)
#     U                      (ensemble_member_label, time, level, latitude, longitude) float32 354MB ...
#     V                      (ensemble_member_label, time, level, latitude, longitude) float32 354MB ...
#     T                      (ensemble_member_label, time, level, latitude, longitude) float32 354MB ...
# ...

# %%
import cftime

# %%
dir(cftime)
# Out:
# ['CFWarning',
#  'Datetime360Day',
#  'DatetimeAllLeap',
#  'DatetimeGregorian',
#  'DatetimeJulian',
#  'DatetimeNoLeap',
#  'DatetimeProlepticGregorian',
#  'UNIT_CONVERSION_FACTORS',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_cftime',
#  '_dateparse',
#  '_datesplit',
#  '_parse_date',
#  '_strptime',
#  'date2index',
#  'date2num',
#  'datetime',
#  'day_units',
#  'hr_units',
#  'is_leap_year',
#  'microsec_units',
#  'millisec_units',
#  'min_units',
#  'num2date',
#  'num2pydate',
#  'real_datetime',
#  'sec_units',
#  'time2index',
#  'to_tuple']

# %%
# all_files = sorted(glob('/glade/work/dkimpara/CREDIT_runs/latest_skebs/1979-01-01T00Z/*'))
all_files = sorted(glob('/glade/work/dkimpara/CREDIT_runs/prescribed_skebs_rollout/1979-01-01T00Z/*'))

# %%
all_files
# Out:
# ['/glade/work/dkimpara/CREDIT_runs/prescribed_skebs_rollout/1979-01-01T00Z/pred_1979-01-01T00Z_006.nc',
#  '/glade/work/dkimpara/CREDIT_runs/prescribed_skebs_rollout/1979-01-01T00Z/pred_1979-01-01T00Z_012.nc',
#  '/glade/work/dkimpara/CREDIT_runs/prescribed_skebs_rollout/1979-01-01T00Z/pred_1979-01-01T00Z_018.nc',
#  '/glade/work/dkimpara/CREDIT_runs/prescribed_skebs_rollout/1979-01-01T00Z/pred_1979-01-01T00Z_024.nc',
#  '/glade/work/dkimpara/CREDIT_runs/prescribed_skebs_rollout/1979-01-01T00Z/pred_1979-01-01T00Z_030.nc',
#  '/glade/work/dkimpara/CREDIT_runs/prescribed_skebs_rollout/1979-01-01T00Z/pred_1979-01-01T00Z_036.nc',
#  '/glade/work/dkimpara/CREDIT_runs/prescribed_skebs_rollout/1979-01-01T00Z/pred_1979-01-01T00Z_042.nc',
#  '/glade/work/dkimpara/CREDIT_runs/prescribed_skebs_rollout/1979-01-01T00Z/pred_1979-01-01T00Z_048.nc',
#  '/glade/work/dkimpara/CREDIT_runs/prescribed_skebs_rollout/1979-01-01T00Z/pred_1979-01-01T00Z_054.nc',
# ...

# %%
ds = xr.open_dataset(all_files[0])
ds
# Out:
# <xarray.Dataset> Size: 2GB
# Dimensions:                (ensemble_member_label: 50, time: 1, level: 32,
#                             latitude: 192, longitude: 288)
# Coordinates:
#   * time                   (time) datetime64[ns] 8B 1979-01-01T06:00:00
#   * level                  (level) int64 256B 0 1 2 3 4 5 ... 26 27 28 29 30 31
#   * latitude               (latitude) float32 768B -90.0 -89.06 ... 89.06 90.0
#   * longitude              (longitude) float32 1kB 0.0 1.25 2.5 ... 357.5 358.8
#   * ensemble_member_label  (ensemble_member_label) int64 400B 0 1 2 ... 47 48 49
# Data variables: (12/21)
#     U                      (ensemble_member_label, time, level, latitude, longitude) float32 354MB ...
#     V                      (ensemble_member_label, time, level, latitude, longitude) float32 354MB ...
#     T                      (ensemble_member_label, time, level, latitude, longitude) float32 354MB ...
# ...
