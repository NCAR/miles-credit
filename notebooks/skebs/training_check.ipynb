# %%
from credit.data import get_forward_data
from glob import glob
import os
from os.path import join
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
training_log = "/glade/derecho/scratch/dkimpara/CREDIT_runs/skebs_fcnn_scaled_train/training_log.csv"
df = pd.read_csv(training_log)

# %%
df.head()
# Out:
#    index  epoch  train_acc_Qtot_15  valid_acc_Qtot_15  train_std_Qtot_27  \
# 0      0      0           0.975926           0.915303           0.011551
# 1      1      1           0.975927           0.913960           0.011573
# 2      2      2           0.975962           0.913563           0.011584
# 3      3      3           0.975902           0.913058           0.011602
# 4      4      4           0.975936           0.914256           0.011512
#
#    valid_std_Qtot_27  train_acc_PS  valid_acc_PS  train_mae_U_20  \
# 0           0.071757      0.999267      0.994356        0.069025
# 1           0.075977      0.999266      0.994327        0.069072
# 2           0.073021      0.999265      0.994338        0.069086
# 3           0.076651      0.999264      0.994348        0.069022
# 4           0.073179      0.999266      0.994337        0.069086
#
#    valid_mae_U_20  ...  valid_acc_T_5  train_mse_LHFLX  valid_mse_LHFLX  \
# 0        0.141100  ...       0.996432         0.023332         0.079013
# 1        0.143426  ...       0.996484         0.023372         0.079482
# 2        0.142240  ...       0.996413         0.023383         0.079499
# 3        0.142111  ...       0.996459         0.023221         0.078901
# 4        0.143393  ...       0.996463         0.023344         0.078340
#
#    train_mae_V_12  valid_mae_V_12  train_rmse_T_13  valid_rmse_T_13  \
# 0        0.098357        0.202570         0.108551         0.250101
# 1        0.098460        0.206164         0.108508         0.250295
# 2        0.098468        0.208040         0.108610         0.250282
# 3        0.098319        0.207295         0.108471         0.250742
# 4        0.098518        0.206024         0.108622         0.250177
#
#    train_rmse_V_13  valid_rmse_V_13     lr
# 0         0.128952         0.259362  0.005
# 1         0.128956         0.262912  0.005
# 2         0.129114         0.264874  0.005
# 3         0.128855         0.266465  0.005
# 4         0.129248         0.265354  0.005
#
# [5 rows x 1467 columns]

# %%
plt.plot(df.index, df.train_loss, label="train_loss")
plt.plot(df.index, df.valid_loss, label="valid_loss")
plt.legend()
plt.show()

# %%
plt.plot
