# %%
import torch 
import matplotlib.pyplot as plt

# %%
sst_tens = torch.load('./sst.pt')
plt.pcolor(sst_tens.squeeze().cpu().numpy())
plt.show()

# %%
Utens = torch.load('./Vt.pt').squeeze()
plt.pcolor(Utens[-1,:,:].squeeze().cpu().numpy(),cmap='RdBu',vmin=-15, vmax=15)
plt.colorbar()
plt.show()

# %%
sst_tens = torch.load('./FLNS.pt')
plt.pcolor(sst_tens.squeeze().cpu().numpy())
plt.colorbar()
plt.show()

# %%
sst_tens = torch.load('./PS.pt')
plt.pcolor(sst_tens.squeeze().cpu().numpy())
plt.colorbar()
plt.show()

# %%
DS = xr.open_dataset('/glade/campaign/cisl/aiml/wchapman/MLWPS/CESM_RUNS/b.e21.CREDIT_climate_branch_1980/atm/hist/b.e21.CREDIT_climate_branch_1980.cam.h0.1980-09.nc')
DS2 = xr.open_dataset('/glade/campaign/cisl/aiml/wchapman/MLWPS/STAGING/b.e21.CREDIT_climate.statics_1.0deg_32levs_latlon_F32_hyai_fixed.nc')

# %%
DS['hyai']
DS2['hyam'].plot()

# %%
DS2
# Out:
# <xarray.Dataset> Size: 52MB
# Dimensions:       (latitude: 192, longitude: 288, nrdg: 16, ilev: 33, level: 32)
# Coordinates:
#   * latitude      (latitude) float64 2kB -90.0 -89.06 -88.12 ... 89.06 90.0
#   * longitude     (longitude) float64 2kB 0.0 1.25 2.5 ... 356.2 357.5 358.8
#   * ilev          (ilev) float64 264B 2.255 5.032 10.16 ... 967.5 985.1 1e+03
#   * level         (level) float64 256B 3.643 7.595 14.36 ... 957.5 976.3 992.6
# Dimensions without coordinates: nrdg
# Data variables: (12/29)
#     PHIS          (latitude, longitude) float32 221kB ...
#     LANDFRAC      (latitude, longitude) float32 221kB ...
#     SGH           (latitude, longitude) float32 221kB ...
#     SGH30         (latitude, longitude) float32 221kB ...
#     LANDM_COSLAT  (latitude, longitude) float32 221kB ...
#     TERR_UF       (latitude, longitude) float32 221kB ...
#     ...            ...
#     hyai          (ilev) float64 264B ...
#     hybi          (ilev) float32 132B ...
# ...
