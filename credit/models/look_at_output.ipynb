# %%
import xarray as xr
import matplotlib.pyplot as plt

# %%
DS = xr.open_dataset('/glade/derecho/scratch/wchapman/CREDIT/new_pxshf/Post_003steps/runfilt_future_00091/2015-01-01T00Z/pred_2015-01-01T00Z_888.nc')

# %%
DS['U'].squeeze().sel(level=200, method='nearest').plot()
plt.show()
