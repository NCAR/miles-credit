# %%
from credit import interp as inty

import xarray as xr 
import glob 
import matplotlib.pyplot as plt
from scipy.signal import detrend

import numpy as np
import copy
import os 
import sys 
import matplotlib.pyplot as plt 
import glob
import pickle

import cartopy.crs as ccrs

from sklearn.preprocessing import QuantileTransformer
from functools import lru_cache

import math
import copy
from pathlib import Path
from random import random
from functools import partial
from collections import namedtuple
from multiprocessing import cpu_count

from scipy.optimize import linear_sum_assignment
from PIL import Image
from tqdm.auto import tqdm

import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.colors as mcolors
import pandas as pd
from eofs.xarray import Eof
from scipy.ndimage import gaussian_filter

# %% [markdown]
# ## Think about adding dask

# %% [markdown]
# ## Open Necessary Datasets

# %%
model_level_file = '/glade/campaign/cisl/aiml/wchapman/MLWPS/STAGING/f.e21.CREDIT_climate.statics_1.0deg_32levs_latlon_F32_hyai.nc'
DSml = xr.open_dataset(model_level_file)
DSml['level'] = np.arange(0,32)
DSml['ilev'] = np.arange(0,33)
DSml['a_model'] = DSml['hyai']
DSml['b_model'] = DSml['hybi']
DSml.to_netcdf('/glade/work/wchapman/miles_branchs/CESM_physics_multigpu/credit/metadata/CESM_Lev_Info.nc')

#grab emulator data:
FNS = sorted(glob.glob('/glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT*'))
print('... opening model run ...')
DSs = xr.open_mfdataset(FNS[0])
DSs['PHIS'] = DSml['PHIS']
# Out:
# ... opening model run ...

# %%
skip_cell = True

if skip_cell:
    print('skipping this cell')
else: 
    FNS = sorted(glob.glob('/glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT*'))
    
    fp_out = '/glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS/'
    
    for fn in FNS:
        print(fn)
        DSs = xr.open_mfdataset(fn)
        DSs['PHIS'] = DSml['PHIS']
        fn_out = f'{fp_out}/{str(DSs["time"].values)[2:9]}_Pressure_Levels.nc'
    
        if os.path.exists(fn_out):
            print(f'{fn_out} file exists... skipping')
            continue 
        
        interp_fields = ('U', 'V', 'T', 'Qtot')
        q_var = 'Qtot'
        surface_pressure_var = 'PS'
        surface_geopotential_var = 'PHIS'
        levs = np.array([200., 500., 700., 850.])
        model_level_file = '/glade/work/wchapman/miles_branchs/CESM_physics_multigpu/credit/metadata/CESM_Lev_Info.nc'
        DSdo = inty.full_state_pressure_interpolation(DSs, model_level_file = model_level_file,q_var = q_var, interp_fields = interp_fields, 
                                               surface_pressure_var = surface_pressure_var,surface_geopotential_var=surface_geopotential_var,pressure_levels = levs)
        
        ds_avg = DSdo.resample(time='1MS').mean()
        print(f'saved: {fn_out}')
        ds_avg.to_netcdf(fn_out)
# Out:
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1979-01_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1979-01_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1979-02_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1979-02_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1979-03_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1979-03_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1979-04_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1979-04_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1979-05_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1979-05_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1979-06_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1979-06_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1979-07_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1979-07_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1979-08_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1979-08_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1979-09_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1979-09_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1979-10_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1979-10_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1979-11_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1979-11_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1979-12_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1979-12_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1980-01_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1980-01_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1980-02_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1980-02_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1980-03_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1980-03_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1980-04_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1980-04_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1980-05_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1980-05_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1980-06_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1980-06_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1980-07_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1980-07_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1980-08_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1980-08_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1980-09_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1980-09_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1980-10_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1980-10_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1980-11_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1980-11_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1980-12_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1980-12_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1981-01_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1981-01_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1981-02_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1981-02_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1981-03_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1981-03_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1981-04_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1981-04_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1981-05_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1981-05_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1981-06_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1981-06_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1981-07_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1981-07_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1981-08_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1981-08_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1981-09_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1981-09_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1981-10_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1981-10_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1981-11_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1981-11_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1981-12_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1981-12_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1982-01_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1982-01_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1982-02_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1982-02_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1982-03_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1982-03_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1982-04_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1982-04_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1982-05_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1982-05_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1982-06_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1982-06_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1982-07_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1982-07_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1982-08_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1982-08_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1982-09_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1982-09_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1982-10_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1982-10_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1982-11_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1982-11_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1982-12_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1982-12_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1983-01_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1983-01_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1983-02_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1983-02_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1983-03_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1983-03_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1983-04_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1983-04_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1983-05_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1983-05_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1983-06_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1983-06_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1983-07_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1983-07_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1983-08_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1983-08_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1983-09_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1983-09_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1983-10_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1983-10_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1983-11_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1983-11_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1983-12_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1983-12_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1984-01_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1984-01_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1984-02_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1984-02_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1984-03_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1984-03_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1984-04_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1984-04_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1984-05_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1984-05_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1984-06_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1984-06_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1984-07_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1984-07_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1984-08_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1984-08_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1984-09_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1984-09_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1984-10_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1984-10_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1984-11_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1984-11_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1984-12_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1984-12_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1985-01_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1985-01_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1985-02_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1985-02_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1985-03_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1985-03_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1985-04_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1985-04_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1985-05_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1985-05_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1985-06_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1985-06_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1985-07_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1985-07_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1985-08_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1985-08_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1985-09_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1985-09_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1985-10_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1985-10_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1985-11_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1985-11_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1985-12_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1985-12_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1986-01_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1986-01_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1986-02_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1986-02_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1986-03_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1986-03_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1986-04_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1986-04_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1986-05_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1986-05_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1986-06_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1986-06_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1986-07_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1986-07_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1986-08_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1986-08_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1986-09_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1986-09_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1986-10_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1986-10_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1986-11_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1986-11_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1986-12_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1986-12_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1987-01_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1987-01_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1987-02_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1987-02_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1987-03_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1987-03_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1987-04_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1987-04_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1987-05_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1987-05_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1987-06_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1987-06_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1987-07_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1987-07_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1987-08_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1987-08_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1987-09_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1987-09_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1987-10_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1987-10_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1987-11_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1987-11_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1987-12_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1987-12_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1988-01_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1988-01_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1988-02_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1988-02_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1988-03_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1988-03_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1988-04_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1988-04_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1988-05_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1988-05_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1988-06_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1988-06_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1988-07_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1988-07_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1988-08_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1988-08_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1988-09_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1988-09_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1988-10_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1988-10_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1988-11_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1988-11_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1988-12_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1988-12_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1989-01_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1989-01_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1989-02_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1989-02_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1989-03_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1989-03_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1989-04_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1989-04_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1989-05_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1989-05_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1989-06_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1989-06_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1989-07_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1989-07_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1989-08_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1989-08_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1989-09_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1989-09_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1989-10_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1989-10_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1989-11_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1989-11_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1989-12_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1989-12_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1990-01_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1990-01_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1990-02_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1990-02_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1990-03_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1990-03_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1990-04_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1990-04_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1990-05_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1990-05_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1990-06_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1990-06_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1990-07_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1990-07_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1990-08_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1990-08_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1990-09_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1990-09_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1990-10_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1990-10_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1990-11_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1990-11_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1990-12_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1990-12_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1991-01_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1991-01_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1991-02_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1991-02_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1991-03_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1991-03_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1991-04_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1991-04_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1991-05_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1991-05_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1991-06_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1991-06_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1991-07_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1991-07_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1991-08_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1991-08_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1991-09_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1991-09_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1991-10_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1991-10_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1991-11_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1991-11_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1991-12_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1991-12_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1992-01_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1992-01_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1992-02_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1992-02_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1992-03_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1992-03_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1992-04_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1992-04_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1992-05_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1992-05_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1992-06_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1992-06_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1992-07_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1992-07_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1992-08_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1992-08_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1992-09_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1992-09_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1992-10_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1992-10_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1992-11_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1992-11_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_1992-12_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//1992-12_Pressure_Levels.nc file exists... skipping
# ...
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2004-05_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2004-05_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2004-06_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2004-06_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2004-07_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2004-07_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2004-08_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2004-08_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2004-09_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2004-09_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2004-10_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2004-10_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2004-11_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2004-11_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2004-12_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2004-12_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2005-01_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2005-01_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2005-02_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2005-02_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2005-03_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2005-03_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2005-04_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2005-04_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2005-05_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2005-05_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2005-06_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2005-06_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2005-07_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2005-07_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2005-08_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2005-08_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2005-09_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2005-09_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2005-10_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2005-10_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2005-11_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2005-11_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2005-12_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2005-12_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2006-01_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2006-01_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2006-02_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2006-02_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2006-03_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2006-03_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2006-04_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2006-04_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2006-05_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2006-05_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2006-06_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2006-06_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2006-07_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2006-07_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2006-08_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2006-08_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2006-09_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2006-09_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2006-10_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2006-10_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2006-11_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2006-11_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2006-12_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2006-12_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2007-01_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2007-01_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2007-02_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2007-02_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2007-03_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2007-03_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2007-04_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2007-04_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2007-05_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2007-05_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2007-06_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2007-06_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2007-07_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2007-07_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2007-08_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2007-08_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2007-09_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2007-09_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2007-10_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2007-10_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2007-11_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2007-11_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2007-12_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2007-12_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2008-01_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2008-01_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2008-02_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2008-02_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2008-03_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2008-03_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2008-04_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2008-04_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2008-05_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2008-05_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2008-06_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2008-06_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2008-07_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2008-07_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2008-08_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2008-08_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2008-09_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2008-09_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2008-10_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2008-10_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2008-11_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2008-11_Pressure_Levels.nc file exists... skipping
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1D/averaged_UVTQtotPSPRECTTREFHT_2008-12_1D.nc
# /glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//2008-12_Pressure_Levels.nc file exists... skipping

# %% [markdown]
# ## CESM

# %%
# %%time
skip_cell = True

if skip_cell:
    print('skipping this cell')
else:
    fp_out = '/glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS/'
    conc = []
    for yryr in range(1979,2009):
        print(f'doing {yryr}')
        conc = xr.open_zarr(f'/glade/campaign/cisl/aiml/wchapman/MLWPS/STAGING/f.e21.CREDIT_climate_{yryr}_ERA5scaled_F32_Qtot.zarr')
        # conc.append(DSdo_1)
    
        print('... resampling and loading ....')
        DSzarr1 = conc[['U', 'V', 'T', 'Qtot','PS']]
        DSzarr1['level']=DSs['level']
        print('... resampling and loading ....')
        DSzarr1 = DSzarr1.resample(time='1D').mean().load()
        print('... resampling and loading ....')
        DSzarr1['PHIS'] = DSml['PHIS']
    
        date_range = pd.date_range(start=f'{yryr}-01', end=f'{yryr}-12', freq='1MS')
    
        for bebop in date_range:
            ddo = DSzarr1.sel(time=str(bebop)[0:7])
    
            fn_out = f'{fp_out}/CESM_{str(bebop)[0:7]}_Pressure_Levels.nc'
        
            if os.path.exists(fn_out):
                print(f'{fn_out} file exists... skipping')
                continue 
            
            interp_fields = ('U', 'V', 'T', 'Qtot')
            q_var = 'Qtot'
            surface_pressure_var = 'PS'
            surface_geopotential_var = 'PHIS'
            levs = np.array([200., 500., 700., 850.])
            model_level_file = '/glade/work/wchapman/miles_branchs/CESM_physics_multigpu/credit/metadata/CESM_Lev_Info.nc'
            DSdo = inty.full_state_pressure_interpolation(ddo, model_level_file = model_level_file,q_var = q_var, interp_fields = interp_fields, 
                                                   surface_pressure_var = surface_pressure_var,surface_geopotential_var=surface_geopotential_var,pressure_levels = levs)
            
            ds_avg = DSdo.resample(time='1MS').mean()
            print(f'saved: {fn_out}')
            ds_avg.to_netcdf(fn_out)
# Out:
# skipping this cell
# CPU times: user 626 μs, sys: 0 ns, total: 626 μs
# Wall time: 578 μs

# %% [markdown]
# ## Modes:

# %%
FNS = sorted(glob.glob('/glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//CESM_*_Pressure_Levels.nc'))
DSall_CESM = xr.open_mfdataset(FNS)
FNS = sorted(glob.glob('/glade/derecho/scratch/wchapman/CREDIT/cesm_wxformer_00191_nb/model_00223_b/1979-01-01T00Z/1MS//????-??_Pressure_Levels.nc'))
DSall = xr.open_mfdataset(FNS)

# %%
# import numpy as np
# import matplotlib.pyplot as plt
# from eofs.standard import Eof  # Ensure eofs library is installed
# from scipy.ndimage import gaussian_filter

mons = [12, 1, 2]  # Months for DJF

# Step 1: Select the winter months (Dec, Jan, Feb) and spatial slice for DSall
print('one')
# Group data into winter seasons by averaging over Dec-Jan-Feb for each year
# Latitude weighting is applied to capture spherical influences
DS_winter = DSall.resample(time='QS-DEC').mean().where(DSall['time'].dt.month.isin(mons), drop=True).sel(latitude=slice(20, 85), longitude=slice(120, 300))

# Extract the geopotential height at 500 hPa and remove the time mean
DSwtot = DS_winter['Z_PRES'].sel(pressure=500).load()
DSwtota = DSwtot - DSwtot.mean('time')

# Step 2: Calculate weights based on cosine of latitude
coslat = np.cos(np.deg2rad(DSwtota.coords['latitude'].values))
wgts = np.sqrt(coslat)[..., np.newaxis]  # Expand dimensions to align with dataset

# Step 3: Perform EOF analysis for PNA extraction
# EOF patterns are computed for the domain (20-85°N, 120°E-120°W)
solver1 = Eof(DSwtota, weights=wgts)  # Create an EOF solver for the dataset
eof1 = solver1.eofsAsCorrelation(neofs=3)  # Extract the first 3 EOFs as correlations
pc1 = solver1.pcs(npcs=3, pcscaling=1)  # Get the first 3 PCs with scaling

# Step 4: Repeat the above for the CESM dataset
print('two')
DS_winter_CESM = DSall_CESM.resample(time='QS-DEC').mean().where(DSall_CESM['time'].dt.month.isin(mons), drop=True).sel(latitude=slice(20, 85), longitude=slice(120, 300))

DSwtot_CESM = DS_winter_CESM['Z_PRES'].sel(pressure=500).load()
DSwtota_CESM = DSwtot_CESM - DSwtot_CESM.mean('time')

coslat = np.cos(np.deg2rad(DSwtota_CESM.coords['latitude'].values))
wgts = np.sqrt(coslat)[..., np.newaxis]

solver2 = Eof(DSwtota_CESM, weights=wgts)
eof2 = solver2.eofsAsCorrelation(neofs=3)
pc2 = solver2.pcs(npcs=3, pcscaling=1)

# Step 5: Plot explained variance for both datasets
solver1.varianceFraction(neigs=5).plot(color='teal', linestyle='--', marker='s', label='CAMulator')
solver2.varianceFraction(neigs=5).plot(color='purple', linestyle='--', marker='s', label='CAM')

plt.title("Explained Variance for EOF Modes")
plt.xlabel("Mode Number")
plt.ylabel("Fraction of Variance")
plt.legend()
plt.grid(color='gray', linestyle='--', linewidth=0.5, alpha=0.7)
plt.show()

# Step 6: Regression of DS_winter and DS_winter_CESM on PC1 (Modes 0, 1)
fig, axes = plt.subplots(2, 2, figsize=(18, 12), subplot_kw={"projection": ccrs.PlateCarree(central_longitude=180)})

for mode in range(2):
    # Flatten spatial dimensions for regression
    DS_winter_flat = DSall.resample(time='QS-DEC').mean().where(DSall['time'].dt.month.isin(mons), drop=True).stack(space=("latitude", "longitude"))['Z_PRES'].sel(pressure=500)
    DS_winter_CESM_flat = DSall_CESM.resample(time='QS-DEC').mean().where(DSall_CESM['time'].dt.month.isin(mons), drop=True).stack(space=("latitude", "longitude"))['Z_PRES'].sel(pressure=500)

    # Compute regression coefficients for DS_winter and DS_winter_CESM
    regression_coeffs_ds = np.dot(DS_winter_flat.values.T, pc1[:, mode]) / np.dot(pc1[:, mode], pc1[:, mode])
    regression_coeffs_cesm = np.dot(DS_winter_CESM_flat.values.T, pc2[:, mode]) / np.dot(pc2[:, mode], pc2[:, mode])

    # Reshape coefficients back to spatial dimensions
    regression_map_ds = regression_coeffs_ds.reshape(DSall["latitude"].size, DSall["longitude"].size)
    regression_map_cesm = regression_coeffs_cesm.reshape(DSall_CESM["latitude"].size, DSall_CESM["longitude"].size)

    # Ensure EOF patterns have the same sign by correlating regression maps
    correlation = np.corrcoef(regression_map_ds.flatten(), regression_map_cesm.flatten())[0, 1]
    if correlation < 0:
        regression_map_cesm = -regression_map_cesm

    # Apply spatial smoothing using Gaussian filter
    smoothed_map_ds = gaussian_filter(regression_map_ds, sigma=1)  # Adjust sigma for smoothing level
    smoothed_map_cesm = gaussian_filter(regression_map_cesm, sigma=1)

    # Plot regression map for DS_winter
    ax = axes[0, mode]
    im = ax.pcolormesh(
        DSall["longitude"], DSall["latitude"], smoothed_map_ds/9.81,
        transform=ccrs.PlateCarree(), cmap="RdBu_r", shading="auto", vmin=-50, vmax=50
    )
    ax.coastlines()
    ax.add_feature(cfeature.BORDERS, linestyle=":")
    ax.add_feature(cfeature.LAND, edgecolor="black", alpha=0.5)
    cbar = plt.colorbar(im, ax=ax, orientation="horizontal", pad=0.05, aspect=40)
    cbar.set_label(f"Z500 Anomalies (m, CAMulator, Mode {mode})", fontsize=12)
    ax.set_title(f"PNA Regression: CAMulator on PC{mode}")

    # Plot regression map for DS_winter_CESM
    ax = axes[1, mode]
    im = ax.pcolormesh(
        DSall["longitude"], DSall["latitude"], smoothed_map_cesm/9.81,
        transform=ccrs.PlateCarree(), cmap="RdBu_r", shading="auto", vmin=-50, vmax=50
    )
    ax.coastlines()
    ax.add_feature(cfeature.BORDERS, linestyle=":")
    ax.add_feature(cfeature.LAND, edgecolor="black", alpha=0.5)
    cbar = plt.colorbar(im, ax=ax, orientation="horizontal", pad=0.05, aspect=40)
    cbar.set_label(f"Z500 Anomalies (m, CAM, Mode {mode})", fontsize=12)
    ax.set_title(f"PNA Regression: CAM on PC{mode}")

plt.tight_layout()
plt.show()
# Out:
# one
# two

# %%
mons = [12, 1, 2]  # Months for DJF

# Step 1: Select the winter months (Dec, Jan, Feb) and spatial slice for DSall
print('one')
# Group data into winter seasons by averaging over Dec-Jan-Feb for each year
# Latitude weighting is applied to capture spherical influences
DS_winter = DSall.resample(time='QS-DEC').mean().where(DSall['time'].dt.month.isin(mons), drop=True).sel(latitude=slice(20, 85), longitude=slice(120, 300))

# Extract the geopotential height at 500 hPa and remove the time mean
DSwtot = DS_winter['Z_PRES'].sel(pressure=500).load()
DSwtota = DSwtot - DSwtot.mean('time')

# Step 2: Calculate weights based on cosine of latitude
coslat = np.cos(np.deg2rad(DSwtota.coords['latitude'].values))
wgts = np.sqrt(coslat)[..., np.newaxis]  # Expand dimensions to align with dataset

# Step 3: Perform EOF analysis for PNA extraction
# EOF patterns are computed for the domain (20-85°N, 120°E-120°W)
solver1 = Eof(DSwtota, weights=wgts)  # Create an EOF solver for the dataset
eof1 = solver1.eofsAsCorrelation(neofs=3)  # Extract the first 3 EOFs as correlations
pc1 = solver1.pcs(npcs=3, pcscaling=1)  # Get the first 3 PCs with scaling

# Step 4: Repeat the above for the CESM dataset
print('two')
DS_winter_CESM = DSall_CESM.resample(time='QS-DEC').mean().where(DSall_CESM['time'].dt.month.isin(mons), drop=True).sel(latitude=slice(20, 85), longitude=slice(120, 300))

DSwtot_CESM = DS_winter_CESM['Z_PRES'].sel(pressure=500).load()
DSwtota_CESM = DSwtot_CESM - DSwtot_CESM.mean('time')

coslat = np.cos(np.deg2rad(DSwtota_CESM.coords['latitude'].values))
wgts = np.sqrt(coslat)[..., np.newaxis]

solver2 = Eof(DSwtota_CESM, weights=wgts)
eof2 = solver2.eofsAsCorrelation(neofs=3)
pc2 = solver2.pcs(npcs=3, pcscaling=1)

# Step 5: Add NAO Analysis
# NAO domain: 20-80°N, 90°W-40°E
DS_nao = DSall.sel(latitude=slice(20, 88), longitude=((DSall.longitude >= 270) | (DSall.longitude <= 40)))
DS_nao_CESM = DSall_CESM.sel(latitude=slice(20, 88), longitude=((DSall_CESM.longitude >= 270) | (DSall_CESM.longitude <= 40)))

DS_nao = DS_nao.resample(time='QS-DEC').mean().where(DS_nao['time'].dt.month.isin(mons), drop=True)
DS_nao_CESM = DS_nao_CESM.resample(time='QS-DEC').mean().where(DS_nao_CESM['time'].dt.month.isin(mons), drop=True)

DS_nao_z500 = DS_nao['Z_PRES'].sel(pressure=500) - DS_nao['Z_PRES'].sel(pressure=500).mean('time')
DS_nao_CESM_z500 = DS_nao_CESM['Z_PRES'].sel(pressure=500) - DS_nao_CESM['Z_PRES'].sel(pressure=500).mean('time')

# Fix for applying weights in the Eof solver
latitude_weights = np.sqrt(np.cos(np.deg2rad(DS_nao_z500['latitude'].values)))
weights = np.broadcast_to(latitude_weights[:, np.newaxis], DS_nao_z500.shape[1:])

solver_nao = Eof(DS_nao_z500, weights=weights)
solver_nao_CESM = Eof(DS_nao_CESM_z500, weights=weights)

nao_pc1 = solver_nao.pcs(npcs=1, pcscaling=1)  # Leading EOF for NAO
nao_pc1_CESM = solver_nao_CESM.pcs(npcs=1, pcscaling=1)

# Step 6: Plot explained variance for both datasets
solver1.varianceFraction(neigs=5).plot(color='teal', linestyle='--', marker='s', label='CAMulator')
solver2.varianceFraction(neigs=5).plot(color='purple', linestyle='--', marker='s', label='CAM')
plt.title("Explained Variance for EOF Modes (PNA)")
plt.xlabel("Mode Number")
plt.ylabel("Fraction of Variance")
plt.legend()
plt.grid(color='gray', linestyle='--', linewidth=0.5, alpha=0.7)
plt.show()

solver_nao.varianceFraction(neigs=5).plot(color='blue', linestyle='--', marker='o', label='CAMulator (NAO)')
solver_nao_CESM.varianceFraction(neigs=5).plot(color='orange', linestyle='--', marker='o', label='CAM (NAO)')
plt.title("Explained Variance for EOF Modes (NAO)")
plt.xlabel("Mode Number")
plt.ylabel("Fraction of Variance")
plt.legend()
plt.grid(color='gray', linestyle='--', linewidth=0.5, alpha=0.7)
plt.show()

print('plotting')
# Step 7: Regression Analysis for NAO
fig, axes = plt.subplots(2, 2, figsize=(18, 12), subplot_kw={"projection": ccrs.NorthPolarSteereo()})
loop = 0
for mode, pc_nao, pc_nao_CESM, solver, title_suffix in zip([0, 0], [pc1, nao_pc1], [pc2, nao_pc1_CESM], [[solver1, solver2], [solver_nao, solver_nao_CESM]], ["PNA","NAO"]):

    # Flatten spatial dimensions for regression
    DS_nao_flat =  DSall.resample(time='QS-DEC').mean().where(DSall['time'].dt.month.isin(mons), drop=True).stack(space=("latitude", "longitude"))['Z_PRES'].sel(pressure=500)
    DS_nao_CESM_flat = DSall_CESM.resample(time='QS-DEC').mean().where(DSall_CESM['time'].dt.month.isin(mons), drop=True).stack(space=("latitude", "longitude"))['Z_PRES'].sel(pressure=500)


    # Regression coefficients for NAO
    regression_coeffs_nao = np.dot(DS_nao_flat.values.T, pc_nao[:, mode]) / np.dot(pc_nao[:, mode], pc_nao[:, mode])
    regression_coeffs_nao_CESM = np.dot(DS_nao_CESM_flat.values.T, pc_nao_CESM[:, mode]) / np.dot(pc_nao_CESM[:, mode], pc_nao_CESM[:, mode])

    # Reshape coefficients back to spatial dimensions
    regression_map_ds = regression_coeffs_nao.reshape(DSall["latitude"].size, DSall["longitude"].size)
    regression_map_cesm = regression_coeffs_nao_CESM.reshape(DSall_CESM["latitude"].size, DSall_CESM["longitude"].size)

    # Apply spatial smoothing using Gaussian filter
    smoothed_map_ds = gaussian_filter(regression_map_ds, sigma=1)  # Adjust sigma for smoothing level
    smoothed_map_cesm = gaussian_filter(regression_map_cesm, sigma=1)

    # Plot regression map for DS_winter
    ax = axes[0, loop]
    im = ax.pcolormesh(
        DSall["longitude"], DSall["latitude"], smoothed_map_ds/9.81,
        transform=ccrs.PlateCarree(), cmap="RdBu_r", shading="auto", vmin=-50, vmax=50
    )
    ax.coastlines()
    ax.add_feature(cfeature.BORDERS, linestyle=":")
    ax.add_feature(cfeature.LAND, edgecolor="black", alpha=0.5)
    cbar = plt.colorbar(im, ax=ax, orientation="horizontal", pad=0.05, aspect=40)
    cbar.set_label(f"Z500 Anomalies (m, CAMulator, Mode {mode})", fontsize=12)
    ax.set_title(f"{title_suffix}  Regression: CAMulator on PC{mode}")

    # Plot regression map for DS_winter_CESM
    ax = axes[1, loop]
    im = ax.pcolormesh(
        DSall["longitude"], DSall["latitude"], smoothed_map_cesm/9.81,
        transform=ccrs.PlateCarree(), cmap="RdBu_r", shading="auto", vmin=-50, vmax=50
    )
    ax.coastlines()
    ax.add_feature(cfeature.BORDERS, linestyle=":")
    ax.add_feature(cfeature.LAND, edgecolor="black", alpha=0.5)
    cbar = plt.colorbar(im, ax=ax, orientation="horizontal", pad=0.05, aspect=40)
    cbar.set_label(f"Z500 Anomalies (m, CAM, Mode {mode})", fontsize=12)
    ax.set_title(f"{title_suffix} Regression: CAM on PC{mode}")
    loop+=1

plt.tight_layout()
plt.show()
# Out:
# one
# two
# plotting

# %%
print('plotting')
# Step 7: Regression Analysis for NAO
fig, axes = plt.subplots(2, 2, figsize=(18, 12), subplot_kw={"projection": ccrs.NorthPolarStereo()})
plt.subplots_adjust(hspace=0.1, wspace=-0.1)
loop = 0
for mode, pc_nao, pc_nao_CESM, solver, title_suffix in zip([0, 0], [pc1, nao_pc1], [pc2, nao_pc1_CESM], [[solver1, solver2], [solver_nao, solver_nao_CESM]], ["PNA","NAO"]):

    # Flatten spatial dimensions for regression
    DS_nao_flat =  DSall.resample(time='QS-DEC').mean().where(DSall['time'].dt.month.isin(mons), drop=True).stack(space=("latitude", "longitude"))['Z_PRES'].sel(pressure=500)
    DS_nao_CESM_flat = DSall_CESM.resample(time='QS-DEC').mean().where(DSall_CESM['time'].dt.month.isin(mons), drop=True).stack(space=("latitude", "longitude"))['Z_PRES'].sel(pressure=500)


    # Regression coefficients for NAO
    regression_coeffs_nao = np.dot(DS_nao_flat.values.T, pc_nao[:, mode]) / np.dot(pc_nao[:, mode], pc_nao[:, mode])
    regression_coeffs_nao_CESM = np.dot(DS_nao_CESM_flat.values.T, pc_nao_CESM[:, mode]) / np.dot(pc_nao_CESM[:, mode], pc_nao_CESM[:, mode])

    # Reshape coefficients back to spatial dimensions
    regression_map_ds = regression_coeffs_nao.reshape(DSall["latitude"].size, DSall["longitude"].size)
    regression_map_cesm = regression_coeffs_nao_CESM.reshape(DSall_CESM["latitude"].size, DSall_CESM["longitude"].size)

    # Apply spatial smoothing using Gaussian filter
    smoothed_map_ds = gaussian_filter(regression_map_ds, sigma=1)  # Adjust sigma for smoothing level
    smoothed_map_cesm = gaussian_filter(regression_map_cesm, sigma=1)

    if loop == 0:
        cmap = 'RdBu_r'
    else:
        cmap = 'PRGn'
    # Plot regression map for DS_winter
    ax = axes[0, loop]
    im = ax.pcolormesh(
        DSall["longitude"], DSall["latitude"], smoothed_map_ds/9.81,
        transform=ccrs.PlateCarree(), cmap=cmap, shading="auto", vmin=-50, vmax=50
    )
    ax.coastlines()
    ax.set_extent([-180, 180, 25, 90], crs=ccrs.PlateCarree())
    ax.gridlines()
    ax.add_feature(cfeature.BORDERS, linestyle=":")
    ax.add_feature(cfeature.LAND, edgecolor="black", alpha=0.5)
    cbar = plt.colorbar(im, ax=ax, orientation="horizontal", pad=0.05, aspect=20, shrink=0.5)
    cbar.set_label(f"Z500 Anomalies ([m], CAMulator, Mode {mode})", fontsize=12)
    ax.set_title(f"{title_suffix}  Regression: CAMulator")

    # Plot regression map for DS_winter_CESM
    ax = axes[1, loop]
    im = ax.pcolormesh(
        DSall["longitude"], DSall["latitude"], smoothed_map_cesm/9.81,
        transform=ccrs.PlateCarree(), cmap=cmap, shading="auto", vmin=-50, vmax=50
    )
    ax.coastlines()
    ax.set_extent([-180, 180, 25, 90], crs=ccrs.PlateCarree())
    ax.gridlines()
    ax.add_feature(cfeature.BORDERS, linestyle=":")
    ax.add_feature(cfeature.LAND, edgecolor="black", alpha=0.5)
    cbar = plt.colorbar(im, ax=ax, orientation="horizontal", pad=0.05, aspect=20, shrink=0.5)
    cbar.set_label(f"Z500 Anomalies ([m], CAM, Mode {mode})", fontsize=12)
    ax.set_title(f"{title_suffix} Regression: CAM")
    loop+=1
plt.subplots_adjust(hspace=0.1, wspace=-0.4)
# plt.tight_layout()
plt.show()
# Out:
# plotting
